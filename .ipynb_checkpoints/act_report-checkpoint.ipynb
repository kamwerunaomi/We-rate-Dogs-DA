# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### ACT REPORT

# %% [markdown]
# Through some analysis and visulizations of the data, I came up with a few insights.
# 1. Most of the dogs are given a rating of 12
# 2. Pupper is the most popular dog stage and floofer is the least however majority did not have a dog stage specified.
# 3. The mean rating numerator is 10, whereas the min rating is 0 and the max is 75

# %% [markdown]
# ##### Pupper is the most popular dog stage and floofer is the least however majority did not have a dog stage specified.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the visualization above, we can see that pupper is the most popular dog stage while floofer is the least popular. However, it is also noted that majority of the dogs in the data did not have a dog stage specified and were included in the findings.

# %% [markdown]
# ##### Most of the dogs are given a rating of 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the above visualization, we can see that most dogs have the rating 12.

# %% [markdown]
# ##### The mean rating numerator is 10 whereas the min rating is 0 and the max is 75

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the above figure containing the description of the dataset, we can see that the minimum rating numerator is 0 and the maximum rating numerator is 75 and the mean is 10.

# %% [markdown]
# ##### The most tweeted dog

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the above visualization, we can see that dogs between doggo and puppo stages are the most tweeted dogs.

# %% [markdown]
# ##### Dogs with the highest ratings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the above visualizations, we can see that again dogs between doggo and puppo stages have the highest ratings.
